# %%
import matplotlib.pyplot as plt 
import matplotlib

import sys
print(sys.version)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
import numpy as np

pd.set_option("display.max_rows", 400)
import pickle as pkl
import pyodbc

# %matplotlib inline

connection_string = ("DRIVER=/opt/homebrew/Cellar/freetds/1.3.18/lib/libtdsodbc.so;" + 
                     "SERVER=localhost; " +
                     "PORT=1433; " +
                     "UID=sa; " +
                     "PWD=<YourStrong@Passw0rd>; " +
                     "DATABASE=pd; " +
                     "UseNTLMv2=yes;TDS_Version=8.0;")


color_dict = {
    'mgb': '#00b2ca',
    'optum': '#1d4e89',
    'fox': '#ffa041',
    'hbs': '#bb6a02',
}

cn = pyodbc.connect(connection_string, autocommit=True)

# %%
code_dict = {'depression_icd9': ['296.2', '296.20', '296.21', '296.22', '296.23', '296.24', '296.25', '296.26', 
                                 '296.3', '296.30', '296.31', '296.32', '296.33', '296.34', '296.35', '296.36', 
                                 '296.82', '311'],
             'depression_icd10': ['F32.9', 'F32.0', 'F32.1', 'F32.2', 'F32.3', 'F32.4', 'F32.5', 'F33.40', 
                                  'F33.9', 'F33.0', 'F33.1', 'F33.2', 'F33.3', 'F33.40', 'F33.41', 'F33.42', 
                                  'F32.89'],
             'fractures_icd9': ['800.00', '800.01', '800.02', '800.03', '800.04', '800.05', '800.06', '800.09', 
                                '800.1', '800.11', '800.12', '800.13', '800.14', '800.15', '800.16', '800.19', 
                                '800.30', '800.31', '800.32', '800.34', '800.35', '800.36', '800.39', '800.4', 
                                '800.41', '800.42', '800.43', '800.45', '800.46', '800.49', '800.50', '800.51', 
                                '800.52', '800.53', '800.54', '800.55', '800.56', '800.59', '800.60', '800.61', 
                                '800.62', '800.63', '800.64', '800.65', '800.66', '800.69', '800.70', '800.71', 
                                '800.72', '800.73', '800.74', '800.75', '800.76', '800.79', '800.80', '800.81', 
                                '800.82', '800.83', '800.84', '800.85', '800.86', '800.89', '800.90', '800.91',
                                '800.92', '800.93', '800.94', '800.95', '800.96', '800.99', '801.00', '801.01', 
                                '801.03', '801.04', '801.05', '801.06', '801.09', '801.10', '801.11', '801.12', 
                                '801.13', '801.14', '801.15', '801.16', '801.19', '801.20', '801.21', '801.22', 
                                '801.23', '801.24', '801.25', '801.26', '801.29', '801.30', '801.31', '801.32', 
                                '801.33', '801.34', '801.35', '801.36', '801.39', '801.40', '801.41', '801.42', 
                                '801.43', '801.44', '801.45', '801.46', '801.49', '801.50', '801.51', '801.52',
                                '801.53', '801.54', '801.55', '801.56', '801.59', '801.60', '801.61', '801.62', 
                                '801.63', '801.64', '801.65', '801.66', '801.69', '801.70', '801.71', '801.72', 
                                '801.73', '801.74', '801.75', '801.76', '801.79', '801.80', '801.81', '801.82',
                                '801.83', '801.84', '801.85', '801.86', '801.89', '801.90', '801.91', '801.92',
                                '801.93', '801.94', '801.95', '801.96', '801.99', '802', '802.0', '802.1', 
                                '802.2', '802.20', '802.21', '802.22', '802.23', '802.24', '802.25', '802.26',
                                '802.27', '802.28', '802.29', '802.3', '802.30', '802.31', '802.32', '802.33', 
                                '802.34', '802.35', '802.36', '802.37', '802.38', '802.39', '802.4', '802.5', 
                                '802.6', '802.7', '802.8', '802.9', '803.00', '803.01', '803.02', '803.04', 
                                '803.05', '803.06', '803.09', '803.10', '803.11', '803.12', '803.13', '803.14',
                                '803.15', '803.16', '803.19', '803.20', '803.21', '803.22', '803.23', '803.24',
                                '803.25', '803.26', '803.29', '803.30', '803.31', '803.32', '803.33', '803.34',
                                '803.35', '803.36', '803.39', '803.40', '803.41', '803.42', '803.43', '803.44',
                                '803.45', '803.46', '803.49', '803.50', '803.51', '803.52', '803.53', '803.54', 
                                '803.55', '803.56', '803.59', '803.60', '803.61', '803.62', '803.63', '803.64', 
                                '803.65', '803.66', '803.69', '803.70', '803.71', '803.72', '803.73', '803.74',
                                '803.75', '803.76', '803.79', '803.80', '803.81', '803.82', '803.83', '803.84',
                                '803.85', '803.86', '803.89', '803.90', '803.91', '803.92', '803.93', '803.94',
                                '803.95', '803.96', '803.99', '804.00', '804.01', '804.02', '804.03', '804.04',
                                '804.05', '804.06', '804.09', '804.10', '804.11', '804.12', '804.13', '804.14',
                                '804.15', '804.16', '804.19', '804.20', '804.21', '804.22', '804.23', '804.24',
                                '804.25', '804.26', '804.29', '804.30', '804.31', '804.32', '804.33', '804.34',
                                '804.35', '804.36', '804.39', '804.40', '804.41', '804.42', '804.43', '804.44',
                                '804.45', '804.46', '804.49', '804.50', '804.51', '804.52', '804.53', '804.54', 
                                '804.55', '804.56', '804.59', '804.60', '804.61', '804.62', '804.63', '804.64', 
                                '804.65', '804.66', '804.69', '804.70', '804.71', '804.72', '804.73', '804.74', 
                                '804.75', '804.76', '804.79', '804.80', '804.81', '804.82', '804.83', '804.84', 
                                '804.85', '804.86', '804.89', '804.90', '804.91', '804.92', '804.93', '804.94', 
                                '804.95', '804.96', '804.99', '805.00', '805.01', '805.02', '805.03', '805.04',
                                '805.05', '805.06', '805.07', '805.08', '805.10', '805.11', '805.12', '805.13',
                                '805.14', '805.15', '805.16', '805.17', '805.18', '805.2', '805.3', '805.4', 
                                '805.6', '805.7', '805.8', '805.9', '806', '806.00', '806.01', '806.02', 
                                '806.03', '806.04', '806.05', '806.06', '806.07', '806.08', '806.09', '806.1', 
                                '806.10', '806.11', '806.12', '806.13', '806.14', '806.15', '806.16', '806.17',
                                '806.18', '806.19', '806.2', '806.20', '806.21', '806.22', '806.23', '806.24', 
                                '806.25', '806.26', '806.27', '806.28', '806.29', '806.3', '806.30', '806.31', 
                                '806.32', '806.33', '806.34', '806.35', '806.36', '806.37', '806.38', '806.39', 
                                '806.4', '806.5', '806.6', '806.60', '806.61', '806.62', '806.69', '806.7', 
                                '806.70', '806.71', '806.72', '806.79', '806.8', '806.9', '807', '807.00', 
                                '807.01', '807.02', '807.03', '807.04', '807.05', '807.06', '807.07', '807.08', 
                                '807.09', '807.10', '807.11', '807.12', '807.13', '807.14', '807.15', '807.16', 
                                '807.17', '807.18', '807.19', '807.2', '807.3', '808', '808.0', '808.1', 
                                '808.2', '808.3', '808.4', '808.43', '808.44', '808.49', '809', '809.0', 
                                '809.1', '810', '810.00', '810.01', '810.02', '810.03', '810.10', '810.11', 
                                '810.12', '810.13', '811.00', '811.01', '811.02', '811.03', '811.09', '811.10', 
                                '811.11', '811.12', '811.13', '811.19', '812', '812.00', '812.01', '812.02', 
                                '812.03', '812.10', '812.11', '812.12', '812.13', '813', '813.00', '813.01', 
                                '813.03', '813.04', '813.05', '813.06', '813.07', '813.08', '813.10', '813.11', 
                                '813.12', '813.13', '813.14', '813.15', '813.16', '813.17', '813.18', '813.20', 
                                '813.21', '813.22', '813.23', '813.30', '813.31', '813.32', '813.33', '813.40', 
                                '813.41', '813.42', '813.43', '813.44', '813.45', '813.46', '813.47', '813.50', 
                                '813.51', '813.52', '813.53', '813.54', '813.80', '813.81', '813.82', '813.83', 
                                '813.90', '813.91', '813.92', '813.93', '814.00', '814.01', '814.02', '814.03', 
                                '814.04', '814.05', '814.06', '814.07', '814.08', '814.09', '814.10', '814.11', 
                                '814.12', '814.13', '814.14', '814.15', '814.16', '814.17', '814.18', '814.19', 
                                '815.00', '815.01', '815.02', '815.03', '815.04', '815.09', '815.10', '815.11',
                                '815.12', '815.13', '815.14', '815.19', '816.00', '816.01', '816.02', '816.03', 
                                '816.10', '816.11', '816.12', '816.13', '817.0', '817.1', '818.0', '818.1', 
                                '819.0', '819.1', '820.00', '820.01', '820.02', '820.03', '820.09', '820.10', 
                                '820.11', '820.12', '820.13', '820.19', '820.20', '820.21', '820.22', '820.30', 
                                '820.31', '820.32', '820.8', '820.9', '821.00', '821.01', '821.10', '821.11', 
                                '821.20', '821.21', '821.22', '821.23', '821.29', '821.30', '821.31', '821.32', 
                                '821.33', '821.39', '822', '822.1', '823.00', '823.01', '823.02', '823.10', 
                                '823.11', '823.12', '823.20', '823.21', '823.22', '823.30', '823.31', '823.32', 
                                '823.40', '823.41', '823.42', '823.80', '823.81', '823.82', '823.90', '823.91', 
                                '823.92', '824.0', '824.1', '824.2', '824.3', '824.4', '824.5', '824.6', '824.7', 
                                '824.8', '824.9', '825.0', '825.1', '825.20', '825.21', '825.22', '825.23', 
                                '825.24', '825.25', '825.29', '825.3', '825.31', '825.32', '825.33', '825.34',
                                '825.35', '825.39', '826.0', '826.1', '827.0', '827.1', '828.0', '828.1', 
                                '829.0', '829.1'],
             'fractures_icd10': ['S02.0%%A', 'S02.0%%A', 'S06.9%1A', 'S06.9%2A', 'S02.0%%A', 'S06.9%3A', 
                                 'S06.9%4A', 'S02.0%%A', 'S06.9%5A', 'S02.0%%A', 'S06.9%6A', 'S06.9%9A', 
                                 'S06.0%9A', 'S02.0%%A', 'S06.319A', 'S06.339A', 'S06.330A', 'S02.0%%A', 'S06.330A', 'S02.0%%A', 'S06.331A', 'S06.332A',
'S06.313A', 'S06.314A', 'S06.323A', 'S06.324A', 'S06.333A', 'S06.334A', 'S02.0%%A', 'S06.335A', 'S02.0%%A', 'S06.336A', 'S06.337A',
'S06.338A', 'S06.339A', 'S06.319A', 'S06.329A', 'S06.330A', 'S06.339A', 'S02.0%%A', 'S02.0%%A', 'S06.309A', 'S06.360A', 'S02.0%%A',
'S06.300A', 'S06.360A', 'S06.301A', 'S06.302A', 'S06.361A', 'S06.362A', 'S06.305A', 'S06.365A', 'S06.306A', 'S06.366A', 'S06.367A',
                             'W15.%%%S', 'W07.%%%A', 'W07.%%%D', 'W07.%%%S', 'V00.811A', 'V00.811D', 'V00.812A',
                             'V00.812D', 'V00.818A', 'V00.818D', 'V00.831A', 'V00.831D', 'V00.832A', 'V00.832D',
                             'V00.838A', 'V00.838D', 'W05.0%%A', 'W05.0%%D', 'W05.1%%A', 'W05.1%%D', 'W05.2%%A',
                             'W05.2%%D', 'W06.%%%A', 'W06.%%%D', 'W06.%%%S', 'V00.821A', 'V00.821D', 'V00.822A',
                             'V00.822D', 'V00.828A', 'V00.828D', 'W08.%%%A', 'W08.%%%D', 'W08.%%%S', 'W18.11%A',
                             'W18.11%D', 'W18.12%A', 'W18.12%D', 'V00.891A', 'V00.891D', 'V00.892A', 'V00.892D',
                             'V00.898A', 'V00.898D', 'W00.1%%A', 'W00.1%%D', 'W00.2%%A', 'W00.2%%D', 'W14.%%%A',
                             'W14.%%%D', 'W17.81%A', 'W17.81%D', 'W17.82%A', 'W17.82%D', 'W17.89%A', 'W17.89%D',
                             'V00.181A', 'V00.181D', 'V00.182A', 'V00.182D', 'V00.211A', 'V00.211D', 'V00.212A',
                             'V00.212D', 'V00.221A', 'V00.221D', 'V00.222A', 'V00.222D', 'V00.281A', 'V00.281D',
                             'V00.282A', 'V00.282D', 'V00.381A', 'V00.381D', 'V00.382A', 'V00.382D', 'W00.0%%A',
                             'W00.0%%D', 'W00.9%%A', 'W00.9%%D', 'W01.0%%A', 'W01.0%%D', 'W18.2%%A', 'W18.2%%D',
                             'W18.40%A', 'W18.40%D', 'W18.41%A', 'W18.41%D', 'W18.42%A', 'W18.42%D', 'W18.43%A',
                             'W18.43%D', 'W18.49%A', 'W18.49%D', 'W03.%%%A', 'W03.%%%D', 'V00.188A', 'V00.188D',
                             'V00.218A', 'V00.218D', 'V00.228A', 'V00.228D', 'V00.288A', 'V00.288D', 'V00.388A',
                             'V00.388D', 'W01.10%A', 'W01.10%D', 'W01.110A', 'W01.110D', 'W01.111A', 'W01.111D',
                             'W01.118A', 'W01.118D', 'W01.119A', 'W01.119D', 'W18.02%A', 'W18.02%D', 'W01.190A',
                             'W01.190D', 'W01.198A', 'W01.198D', 'W18.00%A', 'W18.00%D', 'W18.01%A', 'W18.01%D',
                             'W18.09%D', 'W04.%%%A', 'W04.%%%D', 'W18.30%A', 'W18.30%D', 'W18.31%A', 'W18.31%D',
                             'W18.39%A', 'W18.39%D', 'W18.39%S', 'W19.%%%A', 'W19.%%%D', 'W19.%%%S', 'V00.181A',
                             'V00.181D', 'V00.182A', 'V00.182D', 'V00.211A', 'V00.211D', 'V00.212A', 'V00.212D',
                             'V00.221A', 'V00.221D', 'V00.222A', 'V00.222D', 'V00.281A', 'V00.281D', 'V00.282A',
                             'V00.282D', 'V00.381A', 'V00.381D', 'V00.382A', 'V00.382D', 'W00.0%%A', 'W00.0%%D',
                             'W00.9%%A', 'W00.9%%D', 'W01.0%%A', 'W01.0%%D', 'W18.2%%A', 'W18.2%%D', 'W18.40%A',
                             'W18.40%D', 'W18.41%A', 'W18.41%D', 'W18.42%A', 'W18.42%D', 'W18.43%A', 'W18.43%D',
                             'W18.49%A', 'W18.49%D'],
             'urinary_icd9': [],
             'urinary_icd10': [],
             'cognition_icd9': [],
             'cognition_icd10': []
            }

print(len(code_dict))

def code_function(lst):     
    diag_filter = ''
    i=0
    for code in lst:       
        if i>0:
            diag_filter += " OR "
        diag_filter += f"CODE LIKE '{code}'" 
        i+=1
    return diag_filter

def optum_code_function(lst):     
    diag_filter = ''
    i=0
    for code in lst:       
        if i>0:
            diag_filter += " OR "
        diag_filter += f"DIAG LIKE '{code.replace('.', '')}'" 
        i+=1
    return diag_filter

depression_diag_query = f"""
SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.dia WHERE
{code_function(code_dict['depression_icd9'])}
OR {code_function(code_dict['depression_icd10'])}
GROUP BY EMPI
"""

depression_optum_query = f"""
SELECT PTID, MIN(CAST(FirstDate as date)) diag FROM optum.dbo.dia WHERE
{optum_code_function(code_dict['depression_icd9'])}
OR {optum_code_function(code_dict['depression_icd10'])}
GROUP BY PTID
"""

fracture_diag_query = f"""
SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.dia WHERE
{code_function(code_dict['fractures_icd9'])}
OR {code_function(code_dict['fractures_icd10'])}
GROUP BY EMPI
"""

fracture_optum_query = f"""
SELECT PTID, MIN(CAST(FirstDate as date)) diag FROM optum.dbo.dia WHERE
{optum_code_function(code_dict['fractures_icd9'])}
OR {optum_code_function(code_dict['fractures_icd10'])}
GROUP BY PTID
"""

fall_diag_query = f"""
SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.dia WHERE
{code_function(code_dict['falls_icd9'])}
OR {code_function(code_dict['falls_icd10'])}
GROUP BY EMPI
"""

fall_optum_query = f"""
SELECT PTID, MIN(CAST(FirstDate as date)) diag FROM optum.dbo.dia WHERE
{optum_code_function(code_dict['falls_icd9'])}
OR {optum_code_function(code_dict['falls_icd10'])}
GROUP BY PTID
"""

# print(fall_diag_query)
# df = pd.read_sql(fall_diag_query, cn)
# df.shape

# %%
## hbs 

df = pd.read_csv('../data/hbs.csv')

hbs_list = []
date_list = []
for c in df.columns[20:400]:
    if c[-4:].lower() == 'date':
        hbs_list.append(c[:-5])
        date_list.append(c)
hbs_list

df = df[df['Subject Visit']==1]
df = df[df['AgeOnSet']>30]
idx = df.groupby(['Subject ID #'])['Subject Visit'].transform(max) == df['Subject Visit']

df['med_sum'] = df[hbs_list].sum(axis=1)
df['med_init'] = 0
df.loc[df['med_sum']>0, 'med_init'] = 1

df['first_med'] = df[date_list].min(axis=1)
df['years_med'] = pd.to_datetime(df['Date of Visit']).dt.year - df['first_med']
df['year_onset'] = (pd.to_datetime(df['Date of Visit']).dt.year-
                    (df['Age']-df['AgeOnSet'])) #-df['AgeOnSet'])

df.loc[df['med_init']>0, 'onset_to_med'] = (df['first_med']-df['year_onset'])
df.loc[df['med_init']==0, 'onset_to_med'] = df['Age']-df['AgeOnSet']
df.loc[df['onset_to_med'] < 0, 'onset_to_med'] = 0
df.fillna(0, inplace=True)

hbs_all_df = df.copy(deep=True)

## Fox
print('users')
fox_user = pd.read_csv('../data/fox/Users.csv')
print(fox_user.shape)
fox_user = fox_user[fox_user['InitPDDiag'] == 1]
print(fox_user.shape)

print('meds')
fm = pd.read_csv('../data/fox/MedicationsPD.csv')[['fox_insight_id', 'MedsEverPDAge', 'age']]
print(fm.shape)

idx = fm.groupby(['fox_insight_id'], sort=False)['age'].transform(max) == fm['age']
fox_meds = fm[idx].groupby('fox_insight_id')['MedsEverPDAge'].min()

fox_df = fox_user.merge(fox_meds, on='fox_insight_id', how='inner')

fox_df['ldopa_init'] = 0
fox_df.loc[fox_df['InitPDDiagAge']>0, 'ldopa_init'] = 1
display(fox_df['ldopa_init'].value_counts())

fox_df['onset_to_ldopa'] = fox_df['MedsEverPDAge'] - fox_df['InitPDDiagAge']
# fox_df.loc[fox_df['onset_to_ldopa'] < 0, 'onset_to_ldopa'] = 0
fox_df.fillna(0, inplace=True)

fox_all_df = fox_df.copy(deep=True)

# %%
pd_meds = ['adartel', 'amantadine', 'apo-trihex', 'apokyn', 'apomorphine', 'aricept', 'botox', 'botulinum', 'artane', 'azilect', 'benserazide', 'benztropine',
           'bromocriptine', 'carbidopa', 'cogentin', 'comtan', 'deprenyl', 'donepezil', 'droxidopa', 'duodopa', 'duopa', 'dysport', 'ebixa', 'eldepryl', 
           'emasm', 'entacapone', 'equfina', 'ethopropazine', 'exelon', 'galantamine', 'gocovri', 'haruropi', 'inbrija', 'istradefylline', 'kynmobi', 'lecigon', 
           'levodopa', 'lodosyn', 'madopar', 'memantine', 'mirapex', 'mucuna', 'myobloc', 'namenda', 'neupro', 'northera', 'nourianz', 'nouriast', 
           'numient', 'nuplazid', 'ongentys', 'opicapone', 'osmolex', 'parcopa', 'parkin', 'parlodel', 'parsidan', 'parsidol,', 
           'parsitan', 'pimavanserin', 'pramipexole', 'profenamine', 'prolopa', 'rasagiline', 'razadyne',
           'reminyl', 'requip', 'rivastigmine', 'ropinirole', 'rotigotine', 'rytary', 'safinamide', 'selegiline', 'sifrol', 'sinemet', 'stalevo',
           'symmetrel', 'tasmar', 'tolcapone', 'trihexyphenidyl', 'xadago', 'xeomin', 'zelapar']

med_string = f''
for m in pd_meds:
    if med_string == '':
        med_string += f"lower(Medication) LIKE '%{m}%' "
    else:
        med_string += f" OR lower(Medication) LIKE '%{m}%' "

daysToDiag = 730
query = f"""
SELECT ct.EMPI,
       DATEDIFF(day, ct.CoverageStart, ct.FirstDiag) DaysBeforeDiag,
       DATEDIFF(day, ct.FirstDiag, ct.CoverageEnd) DaysAfterDiag,
       CASE WHEN allmeds.MedDay is not null
           THEN 1
           ELSE 0
       END AS EventObserved,
       DATEDIFF(day, ct.FirstDiag, COALESCE(allmeds.MedDay, ct.CoverageEnd)) DaysUntilEvent
       
FROM (SELECT EMPI, CAST(FirstEnc as date) CoverageStart, CAST(FirstDiag as date) as FirstDiag,
      CAST(LastEnc as date) CoverageEnd FROM pd.dbo.CoverageTime WHERE DaysToDiag > {daysToDiag}) ct
JOIN pd.dbo.Dem dem
ON ct.EMPI = dem.EMPI
LEFT JOIN (SELECT EMPI, MIN(CAST(Medication_Date as date)) MedDay FROM pd.dbo.Med WHERE {med_string}
                            GROUP BY EMPI) allmeds
on ct. EMPI = allmeds.EMPI
"""
print(query)
all_med_df = pd.read_sql(query, cn)
all_med_df.shape


all_med_df['DaysUntilEvent'].fillna(0, inplace=True)
all_med_df = all_med_df[all_med_df['DaysUntilEvent']>=0]
all_med_df['YearsUntilEvent'] = all_med_df['DaysUntilEvent']/365

mgb_all_df = all_med_df.copy(deep=True)

## optum 
med_string = f''
for m in pd_meds:
    if med_string == '':
        med_string += f"lower(DRUG_NAME) LIKE '%{m}%' "
    else:
        med_string += f" OR lower(DRUG_NAME) LIKE '%{m}%' "

query = f"""
SELECT p.PTID, DATEDIFF(day, p.FirstMonth, p.FirstPDDate) DaysBeforeDiag,
               DATEDIFF(day, p.FirstPDDate, p.LastMonth)+30 DaysAfterDiag,
               CASE WHEN allmeds.MedDay is not null
                   THEN 1
                   ELSE 0
               END AS EventObserved,
               DATEDIFF(day, p.FirstPDDate, COALESCE(allmeds.MedDay, p.LastMonth)) DaysUntilEvent
FROM (SELECT * FROM optum.dbo.Pat 
      WHERE COUNTPD > 2 
      AND DATEDIFF(day, FirstMonth, FirstPDDate) > 730
      AND DATEDIFF(day, FirstPDDate, LastMonth) > 365
    ) p
JOIN (SELECT PTID FROM optum.dbo.Med GROUP BY PTID) allM 
    ON p.PTID = allM.PTID
LEFT JOIN (SELECT PTID, MIN(CAST(FirstDate as date)) MedDay FROM optum.dbo.Med WHERE {med_string}
                            GROUP BY PTID) allmeds
on p.PTID = allmeds.PTID
"""
print(query)
df = pd.read_sql(query, cn)
df.shape

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365

o_all_df = df.copy(deep=True)

# %%
# A - Levodopa Initiation
#MGB
query = f"""
SELECT ct.EMPI,
       DATEDIFF(day, ct.CoverageStart, ct.FirstDiag) DaysBeforeDiag,
       DATEDIFF(day, ct.FirstDiag, ct.CoverageEnd) DaysAfterDiag,
       CASE WHEN ldopa.LdopaDay is not null
           THEN 1
           ELSE 0
       END AS EventObserved,
       DATEDIFF(day, ct.FirstDiag, COALESCE(ldopa.LdopaDay, ct.CoverageEnd)) DaysUntilEvent
FROM (SELECT EMPI, CAST(FirstEnc as date) CoverageStart, CAST(FirstDiag as date) as FirstDiag,
             CAST(LastEnc as date) CoverageEnd FROM pd.dbo.CoverageTime WHERE DaysToDiag > {daysToDiag}) ct
JOIN pd.dbo.Dem dem
ON ct.EMPI = dem.EMPI
LEFT JOIN (SELECT EMPI, MIN(CAST(Medication_Date as date)) LdopaDay FROM pd.dbo.Med WHERE lower(Medication) LIKE '%sinemet%'
                            OR lower(Medication) LIKE '%dopa%'
                            OR lower(Medication) LIKE '%entacapone%'
                            OR lower(Medication) LIKE '%stalevo%'
                            GROUP BY EMPI) ldopa
ON ct.EMPI = ldopa.EMPI
"""
print(query)
df = pd.read_sql(query, cn)
df.shape

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365

mgb_df = df.copy(deep=True)

# hbs
df = pd.read_csv('../data/hbs.csv')
# df = df[df['Subject Visit']==1]
df = df[df['AgeOnSet']>30]
idx = df.groupby(['Subject ID #'])['Subject Visit'].transform(max) == df['Subject Visit']
df = df[idx]
display(df['SubjectType'].value_counts())


ldopa = ['Sinemet_CR_25/100', 'Sinemet_CR_50/200', 'sinemet_25/100', 'sinemet_25/250',
         'sinemet_10/100', 'stalevo_50mg', 'stalevo_100mg', 'stalevo_150mg']

ldopa_dates = [l_drug + '_Date'  for l_drug in ldopa]

df['ldopa_sum'] = df[ldopa].sum(axis=1)
df['ldopa_init'] = 0
df.loc[df['ldopa_sum']>0, 'ldopa_init'] = 1

df['first_ldopa'] = df[ldopa_dates].min(axis=1)
df['years_ldopa'] = pd.to_datetime(df['Date of Visit']).dt.year - df['first_ldopa']
df['year_onset'] = (pd.to_datetime(df['Date of Visit']).dt.year-
                         (df['Age']-df['AgeOnSet'])) #-df['AgeOnSet'])

# df['onset_to_ldopa'] = (df['Age']-df['AgeOnSet'])
df.loc[df['ldopa_init']>0, 'onset_to_ldopa'] = (df['first_ldopa']-df['year_onset'])
df.loc[df['ldopa_init']==0, 'onset_to_ldopa'] = df['Age']-df['AgeOnSet']
df.loc[df['onset_to_ldopa'] < 0, 'onset_to_ldopa'] = 0
df.fillna(0, inplace=True)


hbs_df = df.copy(deep=True)

print('grouped meds')
from tqdm import tqdm
tqdm.pandas()

## Optum
query = f"""
SELECT p.PTID, DATEDIFF(day, p.FirstMonth, p.FirstPDDate) DaysBeforeDiag,
               DATEDIFF(day, p.FirstPDDate, p.LastMonth) DaysAfterDiag,
               CASE WHEN m.LdopaDay is not null
                   THEN 1
                   ELSE 0
               END AS EventObserved,
               DATEDIFF(day, p.FirstPDDate, COALESCE(m.LdopaDay, p.LastMonth)) DaysUntilEvent
FROM (SELECT * FROM optum.dbo.Pat 
      WHERE COUNTPD > 2 
      AND DATEDIFF(day, FirstMonth, FirstPDDate) > 730
      AND DATEDIFF(day, FirstPDDate, LastMonth) > 365
    ) p
JOIN (SELECT PTID FROM optum.dbo.Med GROUP BY PTID) allM 
    ON p.PTID = allM.PTID
LEFT JOIN (SELECT PTID, MIN(FirstDate) LdopaDay FROM optum.dbo.Med 
      WHERE lower(DRUG_NAME) LIKE '%sinemet%'
      OR lower(DRUG_NAME) LIKE '%dopa%'
      OR lower(DRUG_NAME) LIKE '%entacapone%'
      OR lower(DRUG_NAME) LIKE '%stalevo%'
      OR lower(DRUG_NAME) LIKE '%caridop%'
      OR lower(DRUG_NAME) LIKE '%levod%'
      GROUP BY PTID) m
ON p.PTID = m.PTID 
"""
print(query)
df = pd.read_sql(query, cn)
df.shape

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365

o_df = df.copy(deep=True)

# %%
import seaborn as sns
from scipy.stats import linregress
plt.style.use('seaborn-white')

# layout = """
#     AABBCC
#     .DDEE.
#     """
layout = """
    BA
    CD
"""

fig = plt.figure(constrained_layout=True, figsize=(12, 15))
ax_dict = fig.subplot_mosaic(layout)


import lifelines
print(lifelines.__version__)

from lifelines import KaplanMeierFitter
from lifelines import plotting
#plt.figure(figsize=(4, 8))
kmf_mgb = KaplanMeierFitter(label='MGB')

follow_time = 10

plot_df = mgb_df
plot_df.loc[plot_df['YearsUntilEvent'] > follow_time, ['YearsUntilEvent', 'EventObserved']] = [follow_time+1, 0]

kmf_mgb.fit(plot_df['YearsUntilEvent'],
            event_observed=plot_df['EventObserved'], 
            label='MGB') 

# ax = plotting.plot_survival_function([kmf_mgb], loc=slice(0, follow_time))
print(list(range(0, follow_time+1, int(follow_time/5))))
kmf_mgb.plot_survival_function(loc=slice(0, follow_time), color=color_dict['mgb'], ax=ax_dict['A'])

df = hbs_df
hbs_kmf = KaplanMeierFitter(label='HBS')

df.loc[df['onset_to_ldopa'] > follow_time, ['onset_to_ldopa', 'ldopa_init']] = [follow_time+1, 0]
hbs_kmf.fit(df['onset_to_ldopa'], event_observed=df['ldopa_init']) 
hbs_kmf.plot_survival_function(loc=slice(0, follow_time), ax=ax_dict['A'], color=color_dict['hbs'])

# exclude because we cannot reliably get ldopa_init from fox at present
# df = fox_df
# fox_kmf = KaplanMeierFitter(label='FOX')

# df.loc[df['onset_to_ldopa'] > follow_time, ['onset_to_ldopa', 'ldopa_init']] = [follow_time+1, 0]
# fox_kmf.fit(df['onset_to_ldopa'], event_observed=df['ldopa_init']) 
# fox_kmf.plot_survival_function(loc=slice(0, follow_time), ax=ax_dict['A'], color='blue')


kmf_optum = KaplanMeierFitter(label='Optum')
plot_df = o_df
plot_df.loc[plot_df['YearsUntilEvent'] > follow_time, ['YearsUntilEvent', 'EventObserved']] = [follow_time+1, 0]

kmf_optum.fit(plot_df['YearsUntilEvent'],
            event_observed=plot_df['EventObserved'], 
            label='Optum') 

# ax = plotting.plot_survival_function([kmf_mgb], loc=slice(0, follow_time))
print(list(range(0, follow_time+1, int(follow_time/5))))
kmf_optum.plot_survival_function(loc=slice(0, follow_time), 
                                                color=color_dict['optum'],
                                                ax=ax_dict['A'])


plotting.add_at_risk_counts(kmf_mgb, hbs_kmf, kmf_optum, 
                            xticks=list(range(0, follow_time+1, int(follow_time/5))), 
                            ax=ax_dict['A'])

ax_dict['A'].set_xlabel("Years from PD Diagnosis")
ax_dict['A'].set_xticks(list(range(0, follow_time+1, 2)))
ax_dict['A'].set_xlim(0, follow_time+1)
ax_dict['A'].set_ylim(0, 1)
ax_dict['A'].set_ylabel("Proportion not started on levodopa")
ax_dict['A'].set_title('B. Levodopa Initiation')

print('hbs median', hbs_kmf.median_survival_time_,
      'mgb median', kmf_mgb.median_survival_time_,
      'optum median:', kmf_optum.median_survival_time_)

## B. all meds
follow_time = 10

plot_df = mgb_all_df
plot_df.loc[plot_df['YearsUntilEvent'] > follow_time, ['YearsUntilEvent', 'EventObserved']] = [follow_time+1, 0]

kmf_mgb.fit(plot_df['YearsUntilEvent'],
            event_observed=plot_df['EventObserved'], 
            label='MGB') 

# ax = plotting.plot_survival_function([kmf_mgb], loc=slice(0, follow_time))
print(list(range(0, follow_time+1, int(follow_time/5))))
kmf_mgb.plot_survival_function(loc=slice(0, follow_time), color=color_dict['mgb'], ax=ax_dict['B'])

df = hbs_all_df
hbs_kmf = KaplanMeierFitter(label='HBS')

df.loc[df['onset_to_med'] > follow_time, ['onset_to_med', 'ldopa_init']] = [follow_time+1, 0]
hbs_kmf.fit(df['onset_to_med'], event_observed=df['med_init']) 
hbs_kmf.plot_survival_function(loc=slice(0, follow_time), ax=ax_dict['B'], color=color_dict['hbs'])

df = fox_all_df
fox_kmf = KaplanMeierFitter(label='FOX')

df.loc[df['onset_to_ldopa'] > follow_time, ['onset_to_ldopa', 'ldopa_init']] = [follow_time+1, 0]
fox_kmf.fit(df['onset_to_ldopa'], event_observed=df['ldopa_init']) 
fox_kmf.plot_survival_function(loc=slice(0, follow_time), ax=ax_dict['B'], color=color_dict['fox'])


kmf_optum = KaplanMeierFitter(label='Optum')
plot_df = o_all_df
plot_df.loc[plot_df['YearsUntilEvent'] > follow_time, ['YearsUntilEvent', 'EventObserved']] = [follow_time+1, 0]

kmf_optum.fit(plot_df['YearsUntilEvent'],
            event_observed=plot_df['EventObserved'], 
            label='Optum') 

# ax = plotting.plot_survival_function([kmf_mgb], loc=slice(0, follow_time))
print(list(range(0, follow_time+1, int(follow_time/5))))
kmf_optum.plot_survival_function(loc=slice(0, follow_time), 
                                                color=color_dict['optum'],
                                                ax=ax_dict['B'])


plotting.add_at_risk_counts(kmf_mgb, hbs_kmf, fox_kmf, kmf_optum, 
                            xticks=list(range(0, follow_time+1, int(follow_time/5))), 
                            ax=ax_dict['B'])

ax_dict['B'].set_xlabel("Years from PD Diagnosis")
ax_dict['B'].set_xticks(list(range(0, follow_time+1, 2)))
ax_dict['B'].set_xlim(0, follow_time+1)
ax_dict['B'].set_ylim(0, 1)
ax_dict['B'].set_ylabel("Proportion not started on any PD Therapeutic")
ax_dict['B'].set_title('A. All PD Therapeutics')


print('hbs', hbs_kmf.median_survival_time_,
      'mgb', kmf_mgb.median_survival_time_,
      'optum', kmf_optum.median_survival_time_,
      'fox', fox_kmf.median_survival_time_
     )


# plt.figure(figsize=(5, 5))
## HY
# mgb
hy_query = """SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.hy WHERE hy > 2.5 GROUP BY EMPI"""

query = f"""
SELECT h.*, ct.DaysToDiag, DATEDIFF(day, ct.FirstDiag, CAST(h.Date as Date)) DiagtoHY,
       ct.CoverageEnd as DaysAFterDiag, DATEDIFF(day, CAST(h.Date as Date), ct.CoverageEnd) DaysAFterHY,
       DATEDIFF(day, ct.FirstDiag, COALESCE(event.Diag, ct.CoverageEnd)) DaysUntilEvent,
       CASE
           WHEN event.diag is not null  THEN 1
           ELSE 0
       END AS EventObserved
FROM pd.dbo.hy h
JOIN  (SELECT EMPI, DaysToDiag, CAST(FirstEnc as date) CoverageStart, CAST(FirstDiag as date) as FirstDiag,
       CAST(LastEnc as date) CoverageEnd
       FROM pd.dbo.CoverageTime WHERE DaysToDiag > {daysToDiag}) ct
ON h.EMPI = ct.EMPI
LEFT JOIN (SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.hy WHERE hy > 2.5 GROUP BY EMPI) event
ON h.EMPI = event.EMPI 
"""
df = pd.read_sql(query, cn)
df.shape

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365
# df['YearsUntilEvent'].hist()
display(df.shape)

from lifelines import KaplanMeierFitter
from lifelines import plotting
mgb_kmf = KaplanMeierFitter(label='MGB')

follow_time=10

plot_df = df.copy(deep=True)
mgb_kmf.fit(plot_df['YearsUntilEvent'],
            event_observed=df['EventObserved']) 
mgb_kmf.plot_survival_function(loc=slice(0, follow_time), color=color_dict['mgb'],
                               ax=ax_dict['C'])


# hbs
df = pd.read_csv('../data/hbs.csv')
# df = df[df['Subject Visit']==1]
df = df[df['AgeOnSet']>30]
df['VisitYear'] = pd.to_datetime(df['Date of Visit']).dt.year

hy_dict = {}
for i, row in df.iterrows():
    if row['Subject ID #'] not in hy_dict:    
        hy_dict[row['Subject ID #']] = {
            'hy_init': 0,
            'hy_length': 0
        }
    
    if hy_dict[row['Subject ID #']]['hy_init'] == 0:    
        hy_dict[row['Subject ID #']]['hy_length'] = ((row['Age']-row['AgeOnSet']))
        hy_init = int(row['HY'] > 2.5)
        hy_dict[row['Subject ID #']]['hy_init'] = hy_init
        
hy_df = pd.DataFrame.from_dict(hy_dict, orient='index')

hbs_kmf = KaplanMeierFitter(label='HBS')


hbs_kmf.fit(hy_df['hy_length'], event_observed=hy_df['hy_init']) 
hbs_kmf.plot_survival_function(loc=slice(0, follow_time), 
                               ax=ax_dict['C'], color=color_dict['hbs'])

# finish plotting
plotting.add_at_risk_counts(mgb_kmf, hbs_kmf, 
                            xticks=list(range(0, follow_time+1, int(follow_time/5))),
                            ax=ax_dict['C'])

ax_dict['C'].set_xlim(0, follow_time+1)
ax_dict['C'].set_ylim(0, 1)
ax_dict['C'].set_xticks(list(range(0, follow_time+1, int(follow_time/5))))
ax_dict['C'].set_xlabel("Years from PD Diagnosis")
ax_dict['C'].set_ylabel("Proportion with H&Y less than 3")
ax_dict['C'].set_title('C. Hoehn & Yahr ≥ 3')
# plt.savefigfigures/fig2_b_HY.svg', dpi=300)

print('hbs', hbs_kmf.median_survival_time_, 'mgb', mgb_kmf.median_survival_time_)


query = f"""
SELECT ct.EMPI, ct.CoverageStart, ct.CoverageEnd, ct.FirstDiag, ct.DaysBeforeDiag, ct.DaysAfterDiag,
       CASE
           WHEN mci.CogImpairDiag is not null THEN 1
           WHEN ari.AdmitDay is not null THEN 1
       ELSE 0
       END AS EventObserved,
       DATEDIFF(day, ct.FirstDiag, COALESCE(mci.CogImpairDiag, ari.AdmitDay, ct.coverageEnd)) DaysUntilEvent
FROM
(SELECT EMPI, CAST(FirstEnc as date) CoverageStart, FirstDiag, DaysToDiag as DaysBeforeDiag, DiagToLastSeen as DaysAfterDiag,
        CAST(LastEnc as date) CoverageEnd FROM pd.dbo.CoverageTime WHERE DaysToDiag > {daysToDiag}) ct
LEFT JOIN (SELECT EMPI, MIN(CAST(Date as date)) CogImpairDiag FROM pd.dbo.Dia WHERE LEFT(CODE, 6) IN ('G31.84', '331.83') GROUP BY EMPI) mci
ON ct.EMPI = mci.EMPI
LEFT JOIN (SELECT EMPI, MIN(CAST(Medication_Date as date)) AdmitDay FROM pd.dbo.Med
           WHERE lower(Medication) LIKE '%aricept%'
                            OR lower(Medication) LIKE '%donepezil%'
                            GROUP BY EMPI) ari
ON ct.EMPI = ari.EMPI
LEFT JOIN (SELECT EMPI, MIN(Start_date) RefDate FROM pd.dbo.rfv
           WHERE lower(Chief_complaint) LIKE '%cognitive%' or lower(Chief_complaint) LIKE '%memory%' GROUP BY EMPI) r
ON ct.EMPI = r.EMPI
WHERE (DATEDIFF(day, ct.FirstDiag, mci.CogImpairDiag) > -1 OR mci.CogImpairDiag is null)
"""

df = pd.read_sql(query, cn)

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365
# df['YearsUntilEvent'].hist()

from lifelines import KaplanMeierFitter
from lifelines import plotting
mgb_kmf = KaplanMeierFitter(label='MGB')

follow_time=10

plot_df = df.copy(deep=True)
mgb_kmf.fit(plot_df['YearsUntilEvent'],
            event_observed=df['EventObserved'], 
            label='MGB') 

mgb_kmf.plot_survival_function(loc=slice(0, follow_time), color=color_dict['mgb'],
                               ax=ax_dict['D'])

## HBS
df = pd.read_csv('../data/hbs.csv')
# df = df[df['Subject Visit']==1]
df = df[df['AgeOnSet']>30]

idx = df.groupby(['Subject ID #'])['Subject Visit'].transform(max) == df['Subject Visit']
df = df[idx]
display(df['SubjectType'].value_counts())

df['year_onset'] = (pd.to_datetime(df['Date of Visit']).dt.year-
                         (df['Age']-df['AgeOnSet']))

df['cd_init'] = 0
df.loc[df['aricept']>0, 'cd_init'] = 1
df.loc[df['MCI']>0, 'cd_init'] = 1

df['VisitYear'] = pd.to_datetime(df['Date of Visit']).dt.year
df['first_cd'] = df[['aricept_date', 'VisitYear']].min(axis=1)
display(df['first_cd'].describe())

df.loc[df['cd_init']>0, 'onset_to_cd'] = (df['first_cd']-df['year_onset'])
df.loc[df['cd_init']==0, 'onset_to_cd'] = df['Age']-df['AgeOnSet']
df.loc[df['onset_to_cd'] < 0, 'onset_to_cd'] = 0
df.fillna(0, inplace=True)

hbs_kmf = KaplanMeierFitter(label='HBS')
df.loc[df['onset_to_cd'] > follow_time, ['onset_to_cd', 'cd_init']] = [follow_time+1, 0]
hbs_kmf.fit(df['onset_to_cd'], event_observed=df['cd_init']) 

print(list(range(0, follow_time+1, int(follow_time/5))))

hbs_kmf.plot_survival_function(loc=list(range(0, follow_time+1, 1)), 
                               ax=ax_dict['D'], 
                               color=color_dict['hbs'])

## Optum
query = """
SELECT p.PTID, p.FirstMonth as CoverageStart, p.LastMonth as CoverageEnd,
       DATEDIFF(day, p.FirstMonth, p.FirstPDDate) as DaysBeforeDiag,
       DATEDIFF(day, p.FirstPDDate, p.LastMonth) as DaysAfterDiag,
       CASE
           WHEN mci.CogImpairDiag is not null THEN 1
           WHEN ari.AdmitDay is not null THEN 1
       ELSE 0
       END AS EventObserved,
       DATEDIFF(day, p.FirstPDDate, COALESCE(mci.CogImpairDiag, ari.AdmitDay, p.LastMonth)) DaysUntilEvent
       FROM (SELECT * FROM optum.dbo.Pat WHERE COUNTPD > 1 
             AND DATEDIFF(day, FirstMonth, FirstPDDate) > 730) p
LEFT JOIN (SELECT PTID, MIN(CAST(FirstDate as date)) CogImpairDiag FROM optum.dbo.Dia WHERE LEFT(DIAG, 5) IN ('G3184', '33183') GROUP BY PTID) mci
ON p.PTID = mci.PTID
LEFT JOIN (SELECT PTID, MIN(CAST(FirstDate as date)) AdmitDay FROM optum.dbo.Med
           WHERE lower(DRUG_NAME) LIKE '%aricept%'
                            OR lower(DRUG_NAME) LIKE '%donepezil%'
                            GROUP BY PTID) ari
ON p.PTID = ari.PTID
"""

df = pd.read_sql(query, cn)

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365
# df['YearsUntilEvent'].hist()

from lifelines import KaplanMeierFitter
from lifelines import plotting
o_kmf = KaplanMeierFitter(label='Optum')

plot_df = df.copy(deep=True)
o_kmf.fit(plot_df['YearsUntilEvent'],
            event_observed=df['EventObserved'], 
            label='Optum') 

o_kmf.plot_survival_function(loc=slice(0, follow_time), 
                             ax=ax_dict['D'], color=color_dict['optum'])


plotting.add_at_risk_counts(mgb_kmf, hbs_kmf, o_kmf, 
                            xticks=list(range(0, follow_time+1, int(follow_time/5))),
                            ax=ax_dict['D'])
ax_dict['D'].set_xlim(0, follow_time+1)
ax_dict['D'].set_ylim(0, 1)
ax_dict['D'].set_xticks(list(range(0, follow_time+1, int(follow_time/5))))
ax_dict['D'].set_xlabel("Years from PD Diagnosis")
ax_dict['D'].set_ylabel("Proportion not diagnosed with Cognitive Decline")
ax_dict['D'].set_title('D. Cognitive Decline')

print('optum', o_kmf.median_survival_time_, 'hbs', hbs_kmf.median_survival_time_, 'mgb', mgb_kmf.median_survival_time_)

plt.savefig('./figures/figure2.png', dpi=300)
plt.show()

# %%
import lifelines
print(lifelines.__version__)

from lifelines import KaplanMeierFitter
from lifelines import plotting
#plt.figure(figsize=(4, 8))


# plt.figure(figsize=(5, 5))
## HY
# mgb
hy_query = """SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.hy WHERE hy > 2.5 GROUP BY EMPI"""

query = f"""
SELECT h.*, ct.DaysToDiag, DATEDIFF(day, ct.FirstDiag, CAST(h.Date as Date)) DiagtoHY,
       ct.CoverageEnd as DaysAFterDiag, DATEDIFF(day, CAST(h.Date as Date), ct.CoverageEnd) DaysAFterHY,
       DATEDIFF(day, ct.FirstDiag, COALESCE(event.Diag, ct.CoverageEnd)) DaysUntilEvent,
       CASE
           WHEN event.diag is not null  THEN 1
           ELSE 0
       END AS EventObserved
FROM pd.dbo.hy h
JOIN  (SELECT EMPI, DaysToDiag, CAST(FirstEnc as date) CoverageStart, CAST(FirstDiag as date) as FirstDiag,
       CAST(LastEnc as date) CoverageEnd
       FROM pd.dbo.CoverageTime WHERE DaysToDiag > {daysToDiag}) ct
ON h.EMPI = ct.EMPI
LEFT JOIN (SELECT EMPI, MIN(CAST(Date as date)) diag FROM pd.dbo.hy WHERE hy > 2.5 GROUP BY EMPI) event
ON h.EMPI = event.EMPI 
"""
df = pd.read_sql(query, cn)
df.shape

df['DaysUntilEvent'].fillna(0, inplace=True)
df = df[df['DaysUntilEvent']>=0]
df['YearsUntilEvent'] = df['DaysUntilEvent']/365
# df['YearsUntilEvent'].hist()
display(df.shape)

from lifelines import KaplanMeierFitter
from lifelines import plotting
mgb_kmf = KaplanMeierFitter(label='MGB')

follow_time=11

mgb_df = df.copy(deep=True)
plot_df = df.copy(deep=True)
mgb_kmf.fit(plot_df['YearsUntilEvent'],
            event_observed=df['EventObserved']) 
# mgb_kmf.plot_survival_function(loc=slice(0, follow_time), color=color_dict['mgb'],
#                                ax=ax_dict['C'])


# hbs
df = pd.read_csv('../data/hbs.csv')
# df = df[df['Subject Visit']==1]
df = df[df['AgeOnSet']>30]
df['VisitYear'] = pd.to_datetime(df['Date of Visit']).dt.year

hy_dict = {}
for i, row in df.iterrows():
    if row['Subject ID #'] not in hy_dict:    
        hy_dict[row['Subject ID #']] = {
            'hy_init': 0,
            'hy_length': 0
        }
    
    if hy_dict[row['Subject ID #']]['hy_init'] == 0:    
        hy_dict[row['Subject ID #']]['hy_length'] = ((row['Age']-row['AgeOnSet']))
        hy_init = int(row['HY'] > 2.5)
        hy_dict[row['Subject ID #']]['hy_init'] = hy_init
        
hy_df = pd.DataFrame.from_dict(hy_dict, orient='index')

hbs_kmf = KaplanMeierFitter(label='HBS')


hbs_kmf.fit(hy_df['hy_length'], event_observed=hy_df['hy_init']) 
# hbs_kmf.plot_survival_function(loc=slice(0, follow_time), 
#                                ax=ax_dict['C'], color=color_dict['hbs'])

# # finish plotting
# plotting.add_at_risk_counts(mgb_kmf, hbs_kmf, 
#                             xticks=list(range(0, follow_time+1, int(follow_time/5))),
#                             ax=ax_dict['C'])

# ax_dict['C'].set_xlim(0, follow_time+1)
# ax_dict['C'].set_ylim(0, 1)
# ax_dict['C'].set_xticks(list(range(0, follow_time+1, int(follow_time/5))))
# ax_dict['C'].set_xlabel("Years from PD Diagnosis")
# ax_dict['C'].set_ylabel("% with H&Y less than 3")
# ax_dict['C'].set_title('C. Hoehn & Yahr ≥ 3')
# plt.savefig('./figures/fig2_b_HY.svg', dpi=300)


T_exp, E_exp = mgb_df.loc[:, 'YearsUntilEvent'], mgb_df.loc[:, 'EventObserved']
T_con, E_con = hy_df.loc[:, 'hy_length'], hy_df.loc[:, 'hy_init']

from lifelines.statistics import logrank_test
results = logrank_test(T_exp, T_con, event_observed_A=E_exp, event_observed_B=E_con)

results.print_summary()

# %%
from lifelines.statistics import survival_difference_at_fixed_point_in_time_test

kmf_exp = KaplanMeierFitter(label="exp").fit(T_exp, E_exp)
kmf_con = KaplanMeierFitter(label="con").fit(T_con, E_con)

print(kmf_exp.median_survival_time_, kmf_con.median_survival_time_)
